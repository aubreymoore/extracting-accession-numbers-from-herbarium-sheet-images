# %% [markdown]
# # Using the OSF API
#
# This Jupyter notebook is based on https://osf.io/rs986/.
#
# Data are extracted from my project at https://osf.io/befgz.
#
# Before starting this tutorial, make sure to create an account on the osf, login to that account, and create an API token by visiting your settings page.
#
# Save your token as an enviornment variable, or replace the enviornment variable below with the text version of your token for local testing.

# %%
import json
import requests
import os
import time
import re
import glob
import pandas as pd

# %%
OSF_API_URL = 'https://api.osf.io/v2/'

OSF_TOKEN = os.environ['OSF_TOKEN']
# Alternative: simply supply OSF_TOKEN as a string
# OSF_TOKEN = 'your_token_goes_here'

# %%
# helper function which adds authentication to our API requests

def get_request(url):
    headers = {'Authorization': 'Bearer {}'.format(OSF_TOKEN)}
    return requests.get(url, headers=headers)

# %%
# helper function to print out our API responses

def pretty_print(json_data):
    print(json.dumps(json_data, indent=4))

# %%
# ID of my project is befgz

url = OSF_API_URL + 'nodes/?filter[id]=befgz&format=jsonapi'
r = get_request(url).json()
pretty_print(r)
# Out:
# {
#     "data": [
#         {
#             "relationships": {
#                 "files": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/files/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "view_only_links": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/view_only_links/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "identifiers": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/identifiers/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "draft_registrations": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/draft_registrations/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "contributors": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/contributors/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "affiliated_institutions": {
#                     "links": {
#                         "self": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/relationships/institutions/?format=jsonapi",
#                             "meta": {}
#                         },
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/institutions/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "citation": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/citation/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "children": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/children/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "comments": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/comments/?filter%5Btarget%5D=befgz&format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "registrations": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/registrations/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "linked_registrations": {
#                     "links": {
#                         "self": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/relationships/linked_registrations/?format=jsonapi",
#                             "meta": {}
#                         },
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/linked_registrations/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "linked_nodes": {
#                     "links": {
#                         "self": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/relationships/linked_nodes/?format=jsonapi",
#                             "meta": {}
#                         },
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/linked_nodes/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "node_links": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/node_links/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "forks": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/forks/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "root": {
#                     "data": {
#                         "type": "nodes",
#                         "id": "befgz"
#                     },
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "wikis": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/wikis/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "preprints": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/preprints/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 },
#                 "logs": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/logs/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 }
#             },
#             "attributes": {
#                 "category": "project",
#                 "fork": false,
#                 "preprint": false,
#                 "description": "",
#                 "current_user_permissions": [
#                     "read",
#                     "write",
#                     "admin"
#                 ],
#                 "date_modified": "2017-12-13T01:11:27.795004",
#                 "title": "Extract accession numbers from herbarium sheet images",
#                 "collection": false,
#                 "registration": false,
#                 "date_created": "2017-11-22T07:04:59.039909",
#                 "current_user_can_comment": true,
#                 "node_license": null,
#                 "public": true,
#                 "tags": []
#             },
#             "type": "nodes",
#             "id": "befgz",
#             "links": {
#                 "self": "https://api.osf.io/v2/nodes/befgz/",
#                 "html": "https://osf.io/befgz/"
#             }
#         }
#     ],
#     "links": {
#         "next": null,
#         "meta": {
#             "per_page": 10,
#             "total": 1
#         },
#         "prev": null,
#         "last": null,
#         "first": null
#     }
# }

# %%
url = 'https://api.osf.io/v2/nodes/befgz/files/?format=jsonapi'
r = get_request(url).json()
pretty_print(r)
# Out:
# {
#     "data": [
#         {
#             "relationships": {
#                 "files": {
#                     "links": {
#                         "related": {
#                             "href": "https://api.osf.io/v2/nodes/befgz/files/osfstorage/?format=jsonapi",
#                             "meta": {}
#                         }
#                     }
#                 }
#             },
#             "attributes": {
#                 "node": "befgz",
#                 "path": "/",
#                 "kind": "folder",
#                 "name": "osfstorage",
#                 "provider": "osfstorage"
#             },
#             "type": "files",
#             "id": "befgz:osfstorage",
#             "links": {
#                 "storage_addons": "https://api.osf.io/v2/addons/?filter%5Bcategories%5D=storage",
#                 "upload": "https://files.osf.io/v1/resources/befgz/providers/osfstorage/",
#                 "new_folder": "https://files.osf.io/v1/resources/befgz/providers/osfstorage/?kind=folder"
#             }
#         }
#     ],
#     "links": {
#         "next": null,
#         "meta": {
#             "per_page": 10,
#             "total": 1
#         },
#         "prev": null,
#         "last": null,
#         "first": null
#     }
# }

# %%
# Get path to osfstorage/images/labels folder

url = 'https://api.osf.io/v2/nodes/befgz/files/osfstorage/?format=jsonapi'
url = url + '&filter[name]=images'
r = get_request(url).json()
images_folder_path = r['data'][0]['attributes']['path']
print 'images_folder_path: ' + images_folder_path

url = OSF_API_URL + 'nodes/befgz/files/osfstorage{}?format=jsonapi'.format(images_folder_path)
url = url + '&filter[name]=labels'
r = get_request(url).json()
labels_folder_path = r['data'][0]['attributes']['path']
print 'labels_folder_path: ' + labels_folder_path
# Out:
# images_folder_path: /5a1bb4d2594d90026ef23992/
# labels_folder_path: /5a2b60f6e08e9b000f9b196c/

# %% [raw]
# # Get first 10 files in /images/all_sheets/
#
# url = OSF_API_URL + 'nodes/befgz/files/osfstorage{}?format=jsonapi'.format(labels_folder_path)
# r = get_request(url).json()
# pretty_print(r)

# %%
# Extract useful info from the response

for a in r['data']:
    pretty_print(a['attributes']['materialized_path'])
    pretty_print(a['links']['download'])    
    pretty_print(a['id'])       
    print
# Out:
# "/images/labels/41532.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8456e08e9b000d9bd45b"
# "5a2b8456e08e9b000d9bd45b"
#
# "/images/labels/41429.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b755ae08e9b000d9bc9d6"
# "5a2b755ae08e9b000d9bc9d6"
#
# "/images/labels/40843.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b7559e08e9b000f9b2fe6"
# "5a2b7559e08e9b000f9b2fe6"
#
# "/images/labels/42358.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b7557e08e9b000d9bc9d2"
# "5a2b7557e08e9b000d9bc9d2"
#
# "/images/labels/42981.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b7556d7a04c00108d1ef1"
# "5a2b7556d7a04c00108d1ef1"
#
# "/images/labels/40156.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b7555d7a04c00108d1eee"
# "5a2b7555d7a04c00108d1eee"
#
# "/images/labels/38916.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b7555d7a04c000d8d355f"
# "5a2b7555d7a04c000d8d355f"
#
# "/images/labels/40489.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b7554d7a04c00108d1eea"
# "5a2b7554d7a04c00108d1eea"
#
# "/images/labels/42957.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b7552d7a04c00108d1ee6"
# "5a2b7552d7a04c00108d1ee6"
#
# "/images/labels/41986.JPG"
# "https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8a1ce08e9b000d9bdfeb"
# "5a2b8a1ce08e9b000d9bdfeb"

# %%
# Get materialized paths and download URLs for all files in osfstorage/images/labels and write these to a file

f = open('labels.txt', 'w')
for page in range(1,1000):
    print 'Requesting page {}'.format(page)
    # Change number of files per page from 10 (default) to 100 (max allowed) to speed up requests a bit
    url = '''{}nodes/befgz/files/osfstorage{}?format=jsonapi&page[size]=100&page={}
       '''.format(OSF_API_URL, labels_folder_path, page)
    try:
        r = get_request(url)
        j = r.json()
    except:
        print('bad response; retrying in 10s')
        time.sleep(10)
        r = get_request(url)
        j = r.json()
    for a in j['data']:
        materialized_path = a['attributes']['materialized_path']
        download_url = a['links']['download']
        f.write('{}, {}\n'.format(materialized_path, download_url))
    if j['links']['next']==None:
        f.close()
        print 'Finished list of images stored in osfstorage/images/labels'
        print 'See labels.txt'
        break
# Out:
# Requesting page 1
# Requesting page 2
# Requesting page 3
# Requesting page 4
# Requesting page 5
# Requesting page 6
# Requesting page 7
# Requesting page 8
# Requesting page 9
# Requesting page 10
# Requesting page 11
# Requesting page 12
# Requesting page 13
# Requesting page 14
# Requesting page 15
# Requesting page 16
# Requesting page 17
# Requesting page 18
# Requesting page 19
# Requesting page 20
# Requesting page 21
# Requesting page 22
# Requesting page 23
# Requesting page 24
# Requesting page 25
# Requesting page 26
# Requesting page 27
# Requesting page 28
# Requesting page 29
# Requesting page 30
# Requesting page 31
# Requesting page 32
# Requesting page 33
# Requesting page 34
# Requesting page 35
# Requesting page 36
# Requesting page 37
# Requesting page 38
# Requesting page 39
# Requesting page 40
# Requesting page 41
# Requesting page 42
# Requesting page 43
# Requesting page 44
# Requesting page 45
# Requesting page 46
# Requesting page 47
# Requesting page 48
# Requesting page 49
# Requesting page 50
# Requesting page 51
# Requesting page 52
# Requesting page 53
# Requesting page 54
# Requesting page 55
# Requesting page 56
# Finished list of images stored in osfstorage/images/labels
# See labels.txt

# %%
# Get path to osfstorage/images/all_sheets folder

url = OSF_API_URL + 'nodes/befgz/files/osfstorage{}?format=jsonapi'.format(images_folder_path)
url = url + '&filter[name]=all_sheets'
r = get_request(url).json()
all_sheets_folder_path = r['data'][0]['attributes']['path']
print 'all_sheets_folder_path: ' + all_sheets_folder_path
# Out:
# images_folder_path: /5a1bb4d2594d90026ef23992/
# all_sheets_folder_path: /5a1c936a594d90026ef2bb32/

# %%
# Get materialized paths and download URLs for all files in osfstorage/images/labels and write these to a file

f = open('all_sheets.txt', 'w')
for page in range(1,1000):
    print 'Requesting page {}'.format(page)
    # Change number of files per page from 10 (default) to 100 (max allowed) to speed up requests a bit
    url = '''{}nodes/befgz/files/osfstorage{}?format=jsonapi&page[size]=100&page={}
       '''.format(OSF_API_URL, all_sheets_folder_path, page)
    try:
        r = get_request(url)
        j = r.json()
    except:
        print('bad response; retrying in 10s')
        time.sleep(10)
        r = get_request(url)
        j = r.json()
    for a in j['data']:
        materialized_path = a['attributes']['materialized_path']
        download_url = a['links']['download']
        f.write('{}, {}\n'.format(materialized_path, download_url))
    if j['links']['next']==None:
        f.close()
        print 'Finished list of images stored in osfstorage/images/all_sheets'
        print 'See all_sheets.txt'
        break
# Out:
# Requesting page 1
# Requesting page 2
# Requesting page 3
# Requesting page 4
# Requesting page 5
# Requesting page 6
# Requesting page 7
# Requesting page 8
# Requesting page 9
# Requesting page 10
# Requesting page 11
# Requesting page 12
# Requesting page 13
# Requesting page 14
# Requesting page 15
# Requesting page 16
# Requesting page 17
# Requesting page 18
# Requesting page 19
# Requesting page 20
# Requesting page 21
# Requesting page 22
# Requesting page 23
# Requesting page 24
# Requesting page 25
# Requesting page 26
# Requesting page 27
# Requesting page 28
# Requesting page 29
# Requesting page 30
# Requesting page 31
# Requesting page 32
# Requesting page 33
# Requesting page 34
# Requesting page 35
# Requesting page 36
# Requesting page 37
# Requesting page 38
# Requesting page 39
# Requesting page 40
# Requesting page 41
# Requesting page 42
# Requesting page 43
# Requesting page 44
# Requesting page 45
# Requesting page 46
# Requesting page 47
# Requesting page 48
# Requesting page 49
# Requesting page 50
# Requesting page 51
# Requesting page 52
# Requesting page 53
# Requesting page 54
# Requesting page 55
# Requesting page 56
# Finished list of images stored in osfstorage/images/all_sheets
# See all_sheets.txt

# %%
# !ls
# Out:
# all_sheets.txt			 my3.html
# Batch_3048379_batch_results.csv  my.html
# images.txt			 OSF_API_example.ipynb
# image_urls.csv			 OSF_API.ipynb
# labels_sample.csv		 Screenshot from 2017-12-14 15-57-45.png
# labels.txt			 Screenshot from 2017-12-14 16-05-43.png
# labels_urls_plus.csv		 temp
# mturk.html			 turk_answers.csv
# my2.html

# %%
pd.options.display.max_rows = 4
pd.options.display.max_colwidth = 100

# %%
df_labels = pd.read_csv('labels.txt', header=None)
df_labels.columns = ['url1', 'url2']
df_labels
# Out:
#                           url1  \
# 0     /images/labels/39800.JPG
# 1     /images/labels/37947.JPG
# ...                        ...
# 5588  /images/labels/41532.JPG
# 5589  /images/labels/41986.JPG
#
#                                                                                         url2
# 0      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b618fe08e9b000e9b3690
# 1      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b6190e08e9b000f9b19dd
# ...                                                                                      ...
# 5588   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8456e08e9b000d9bd45b
# 5589   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8a1ce08e9b000d9bdfeb
#
# [5590 rows x 2 columns]

# %%
df_all_sheets = pd.read_csv('labels.txt', header=None)
df_all_sheets.columns = ['url1', 'url2']
df_all_sheets
# Out:
#                               url1  \
# 0     /images/all_sheets/37669.JPG
# 1     /images/all_sheets/37649.JPG
# ...                            ...
# 5588  /images/all_sheets/41230.JPG
# 5589  /images/all_sheets/39137.JPG
#
#                                                                                         url2
# 0      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a1c9433594d900270f25280
# 1      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a1c9434b83f69026f97741f
# ...                                                                                      ...
# 5588   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2a8e73e08e9b000f9ab426
# 5589   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2a8f46e08e9b000e9ac40e
#
# [5590 rows x 2 columns]

# %%
n_list = []
for index, row in df_labels.iterrows():
    n = int(re.findall('\\d+', row.url1)[0])
    n_list.append(n)
df_labels['n'] = n_list
df_labels
# Out:
#                           url1  \
# 0     /images/labels/39800.JPG
# 1     /images/labels/37947.JPG
# ...                        ...
# 5588  /images/labels/41532.JPG
# 5589  /images/labels/41986.JPG
#
#                                                                                         url2  \
# 0      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b618fe08e9b000e9b3690
# 1      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b6190e08e9b000f9b19dd
# ...                                                                                      ...
# 5588   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8456e08e9b000d9bd45b
# 5589   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8a1ce08e9b000d9bdfeb
#
#           n
# 0     39800
# 1     37947
# ...     ...
# 5588  41532
# 5589  41986
#
# [5590 rows x 3 columns]

# %%
n_list = []
for index, row in df_all_sheets.iterrows():
    n = int(re.findall('\\d+', row.url1)[0])
    n_list.append(n)
df_all_sheets['n'] = n_list
df_all_sheets
# Out:
#                               url1  \
# 0     /images/all_sheets/37669.JPG
# 1     /images/all_sheets/37649.JPG
# ...                            ...
# 5588  /images/all_sheets/41230.JPG
# 5589  /images/all_sheets/39137.JPG
#
#                                                                                         url2  \
# 0      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a1c9433594d900270f25280
# 1      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a1c9434b83f69026f97741f
# ...                                                                                      ...
# 5588   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2a8e73e08e9b000f9ab426
# 5589   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2a8f46e08e9b000e9ac40e
#
#           n
# 0     37669
# 1     37649
# ...     ...
# 5588  41230
# 5589  39137
#
# [5590 rows x 3 columns]

# %%
df_urls = df_labels.merge(df_all_sheets, on='n')
df_urls.drop(['url1_x','url1_y'], axis=1, inplace=True)
df_urls.columns = ['label_url', 'image_number', 'sheet_url']
df_urls = df_urls[['image_number', 'sheet_url', 'label_url']]
df_urls.to_csv('urls.csv')
df_urls
# Out:
#       image_number  \
# 0            39800
# 1            37947
# ...            ...
# 5588         41532
# 5589         41986
#
#                                                                                    sheet_url  \
# 0      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2240f06c613b027a254e29
# 1      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a223eb1b83f690266bf3117
# ...                                                                                      ...
# 5588   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a1cf5a4b83f690271972d7f
# 5589   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a1ff2749ad5a1026710ec34
#
#                                                                                    label_url
# 0      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b618fe08e9b000e9b3690
# 1      https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b6190e08e9b000f9b19dd
# ...                                                                                      ...
# 5588   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8456e08e9b000d9bd45b
# 5589   https://files.osf.io/v1/resources/befgz/providers/osfstorage/5a2b8a1ce08e9b000d9bdfeb
#
# [5590 rows x 3 columns]
